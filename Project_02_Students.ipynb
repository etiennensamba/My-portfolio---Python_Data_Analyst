# %% [markdown]
# In this project, we will analyze the performance of students in some courses

# %% [markdown]
# Gender
# Race_Ethnicity
# Parental_Level_Of_Education
# Lunch
# Test_Preparation_Course
# Math_Gender
# Writing_Gender
# Parental_Level_Math_Score
# Parental_Level_Read_Score
# Parental_Level_Writing_Score
# Gender_Math_Statistics
# Gender_Reading_Statistics
# Gender_Writing_Statistics
# Parental_Level_Edudation_Scatter

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
Project = pd.read_csv('StudentsPerformance.csv')
Project.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
Project.shape
# Out:
# (1000, 8)

# %%
Columns = Project.columns
Columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
Project.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
Project.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
Project.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
Project.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
Project['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
Project['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
Gender = Project['gender'].value_counts(normalize = True)*100
Gender
# Out:
# female    51.8
# male      48.2
# Name: gender, dtype: float64

# %%
Race_Ethnicity = Project['race/ethnicity'].value_counts(normalize=True)*100
Race_Ethnicity
# Out:
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: race/ethnicity, dtype: float64

# %%
Parental_Level_Of_Education = Project['parental level of education'].value_counts(normalize = True)*100
Parental_Level_Of_Education
# Out:
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: parental level of education, dtype: float64

# %%
Lunch = Project['lunch'].value_counts(normalize = True)*100
Lunch
# Out:
# standard        64.5
# free/reduced    35.5
# Name: lunch, dtype: float64

# %%
Test_Preparation_Course = Project['test preparation course'].value_counts(normalize = True)*100
Test_Preparation_Course
# Out:
# none         64.2
# completed    35.8
# Name: test preparation course, dtype: float64

# %%
Math_Gender = sns.boxplot( data=Project, x='math score', y='gender')
Math_Gender;

# %%
Reading_Gender = sns.boxplot( data=Project, x='reading score', y='gender')
Reading_Gender;

# %%
Writing_Gender = sns.boxplot(data = Project, x= 'writing score', y='gender')
Writing_Gender;

# %%
Parental_Level_Math_Score = sns.boxplot(data = Project, x= 'math score', y= 'parental level of education')
Parental_Level_Math_Score;

# %%
Parental_Level_Read_Score = sns.boxplot(data = Project, x= 'reading score', y= 'parental level of education')
Parental_Level_Read_Score;

# %%
Parental_Level_Writing_Score = sns.boxplot(data = Project, x ='writing score', y='parental level of education')
Parental_Level_Writing_Score;

# %%
Gender_Math_Statistics = Project.groupby(by =['gender']).describe()['math score'].reset_index()
Gender_Math_Statistics
# Out:
#    gender  count       mean        std   min   25%   50%   75%    max
# 0  female  518.0  63.633205  15.491453   0.0  54.0  65.0  74.0  100.0
# 1    male  482.0  68.728216  14.356277  27.0  59.0  69.0  79.0  100.0

# %%
Gender_Reading_Statistics = Project.groupby(by=['gender']).describe()['reading score'].reset_index()
Gender_Reading_Statistics
# Out:
#    gender  count       mean        std   min    25%   50%   75%    max
# 0  female  518.0  72.608108  14.378245  17.0  63.25  73.0  83.0  100.0
# 1    male  482.0  65.473029  13.931832  23.0  56.00  66.0  75.0  100.0

# %%
Gender_Writing_Statistics = Project.groupby(by =['gender']).describe()['writing score'].reset_index()
Gender_Writing_Statistics
# Out:
#    gender  count       mean        std   min   25%   50%    75%    max
# 0  female  518.0  72.467181  14.844842  10.0  64.0  74.0  82.00  100.0
# 1    male  482.0  63.311203  14.113832  15.0  53.0  64.0  73.75  100.0

# %%
Parental_Level_Edudation_Scatter =sns.pairplot(data=Project, hue = 'parental level of education')
Parental_Level_Edudation_Scatter;

# %%
sns.scatterplot(data =Project, x='math score', y='writing score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='writing score'>
